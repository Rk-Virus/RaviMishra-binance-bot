# %% [markdown]
# Importing required modules

# %%
from binance.client import Client
import time
from dotenv import load_dotenv
import os
from tabulate import tabulate

# %% [markdown]
# Loading env variables

# %%
load_dotenv()
API_KEY = os.getenv("API_KEY")
API_SECRET = os.getenv("API_SECRET")

# %% [markdown]
# Initiating binance client

# %%
client = Client(API_KEY, API_SECRET, testnet=True)

# %% [markdown]
# Rest code is given comments for self explaination

# %%
# Fetch account balances
account_data = client.get_account()
print(account_data)
# Out:
# {'makerCommission': 0, 'takerCommission': 0, 'buyerCommission': 0, 'sellerCommission': 0, 'commissionRates': {'maker': '0.00000000', 'taker': '0.00000000', 'buyer': '0.00000000', 'seller': '0.00000000'}, 'canTrade': True, 'canWithdraw': True, 'canDeposit': True, 'brokered': False, 'requireSelfTradePrevention': False, 'preventSor': False, 'updateTime': 1759251958807, 'accountType': 'SPOT', 'balances': [{'asset': 'ETH', 'free': '1.00000000', 'locked': '0.00000000'}, {'asset': 'BTC', 'free': '1.00000000', 'locked': '0.00000000'}, {'asset': 'LTC', 'free': '4.00000000', 'locked': '0.00000000'}, {'asset': 'BNB', 'free': '1.00000000', 'locked': '0.00000000'}, {'asset': 'USDT', 'free': '10000.24854000', 'locked': '0.00000000'}, {'asset': 'TRX', 'free': '1483.00000000', 'locked': '0.00000000'}, {'asset': 'XRP', 'free': '175.00000000', 'locked': '0.00000000'}, {'asset': 'NEO', 'free': '76.00000000', 'locked': '0.00000000'}, {'asset': 'QTUM', 'free': '183.00000000', 'locked': '0.00000000'}, {'asset': 'GAS', 'free': '155.00000000', 'locked': '0.00000000'}, {'asset': 'LRC', 'free': '4956.00000000', 'locked': '0.00000000'}, {'asset': 'ZRX', 'free': '1831.00000000', 'locked': '0.00000000'}, {'asset': 'KNC', 'free': '1349.00000000', 'locked': '0.00000000'}, {'asset': 'IOTA', 'free': '2694.00000000', 'locked': '0.00000000'}, {'asset': 'LINK', 'free': '21.00000000', 'locked': '0.00000000'}, {'asset': 'XVG', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'MTL', 'free': '712.00000000', 'locked': '0.00000000'}, {'asset': 'ETC', 'free': '24.00000000', 'locked': '0.00000000'}, {'asset': 'ZEC', 'free': '12.00000000', 'locked': '0.00000000'}, {'asset': 'DASH', 'free': '20.00000000', 'locked': '0.00000000'}, {'asset': 'REQ', 'free': '4055.00000000', 'locked': '0.00000000'}, {'asset': 'POWR', 'free': '3155.00000000', 'locked': '0.00000000'}, {'asset': 'ENJ', 'free': '7437.00000000', 'locked': '0.00000000'}, {'asset': 'STORJ', 'free': '1972.00000000', 'locked': '0.00000000'}, {'asset': 'BAT', 'free': '3285.00000000', 'locked': '0.00000000'}, {'asset': 'LSK', 'free': '1370.00000000', 'locked': '0.00000000'}, {'asset': 'MANA', 'free': '1567.00000000', 'locked': '0.00000000'}, {'asset': 'ADX', 'free': '3988.00000000', 'locked': '0.00000000'}, {'asset': 'ADA', 'free': '605.00000000', 'locked': '0.00000000'}, {'asset': 'XLM', 'free': '1378.00000000', 'locked': '0.00000000'}, {'asset': 'ICX', 'free': '3914.00000000', 'locked': '0.00000000'}, {'asset': 'RLC', 'free': '387.00000000', 'locked': '0.00000000'}, {'asset': 'PIVX', 'free': '3752.00000000', 'locked': '0.00000000'}, {'asset': 'STEEM', 'free': '3840.00000000', 'locked': '0.00000000'}, {'asset': 'ZIL', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'ONT', 'free': '3664.00000000', 'locked': '0.00000000'}, {'asset': 'WAN', 'free': '4780.00000000', 'locked': '0.00000000'}, {'asset': 'SYS', 'free': '12723.00000000', 'locked': '0.00000000'}, {'asset': 'TUSD', 'free': '10000.00000000', 'locked': '0.00000000'}, {'asset': 'ZEN', 'free': '70.00000000', 'locked': '0.00000000'}, {'asset': 'THETA', 'free': '636.00000000', 'locked': '0.00000000'}, {'asset': 'IOTX', 'free': '18375.00000000', 'locked': '0.00000000'}, {'asset': 'DATA', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'SC', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'DENT', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'ARDR', 'free': '6029.00000000', 'locked': '0.00000000'}, {'asset': 'HOT', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'VET', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'RVN', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'USDC', 'free': '10000.00000000', 'locked': '0.00000000'}, {'asset': 'ONG', 'free': '3049.00000000', 'locked': '0.00000000'}, {'asset': 'FET', 'free': '822.00000000', 'locked': '0.00000000'}, {'asset': 'IOST', 'free': '18446.00000000', 'locked': '0.00000000'}, {'asset': 'CELR', 'free': '18446.00000000' ...

# %%
# Order constraints for bitcoin
symbol = "BTCUSDT"
trade_quantity = 0.001 
buy_price_threshold = 30000 
sell_price_threshold = 35000

# %%
# Buy order function
def place_buy_order(symbol, quantity):
    try:
        order = client.order_market_buy(
            symbol=symbol,
            quantity=quantity
        )
        print("Buy order done:", order)
    except Exception as e:
        print("Error placing buy order:", e)

place_buy_order(symbol, trade_quantity)
# Out:
# Buy order done: {'symbol': 'BTCUSDT', 'orderId': 3821906, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJd8195cbc3ff3b9128f8a80', 'transactTime': 1759259231548, 'price': '0.00000000', 'origQty': '0.00100000', 'executedQty': '0.00100000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '113.74959000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1759259231548, 'fills': [{'price': '113749.59000000', 'qty': '0.00100000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 1002763}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %%
# Sell order function
def place_sell_order(symbol, quantity):
    try:
        order = client.order_market_sell(
            symbol=symbol,
            quantity=quantity
        )
        print("Sell done:", order)
    except Exception as e:
        print("Error placing sell order:", e)

place_sell_order(symbol, trade_quantity)
# Out:
# Sell done: {'symbol': 'BTCUSDT', 'orderId': 3821970, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJbfecbbbf73a0c17de4a769', 'transactTime': 1759259244886, 'price': '0.00000000', 'origQty': '0.00100000', 'executedQty': '0.00100000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '113.71646000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'workingTime': 1759259244886, 'fills': [{'price': '113716.46000000', 'qty': '0.00100000', 'commission': '0.00000000', 'commissionAsset': 'USDT', 'tradeId': 1002775}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %%
# Function to get current price
def get_current_price(symbol):
    ticker = client.get_symbol_ticker(symbol=symbol)
    return float(ticker['price'])

print(get_current_price(symbol))
# Out:
# 113716.47

# %%
# Presenting in tabular format
# Extract balances with non-zero amounts
balances = [
    (b['asset'], b['free'], b['locked'])
    for b in account_data['balances']
    if float(b['free']) > 0 or float(b['locked']) > 0
]

# Print as a table
print(tabulate(
    balances,
    headers=["Asset", "Free", "Locked"],
    tablefmt="fancy_grid"
))
# Out:
# ╒═════════════╤═════════╤══════════╕
# │ Asset       │    Free │   Locked │
# ╞═════════════╪═════════╪══════════╡
# │ ETH         │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BTC         │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LTC         │     4   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BNB         │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ USDT        │ 10000.2 │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TRX         │  1483   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XRP         │   175   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NEO         │    76   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ QTUM        │   183   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GAS         │   155   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LRC         │  4956   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ZRX         │  1831   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KNC         │  1349   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ IOTA        │  2694   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LINK        │    21   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XVG         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MTL         │   712   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ETC         │    24   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ZEC         │    12   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DASH        │    20   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ REQ         │  4055   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ POWR        │  3155   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ENJ         │  7437   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ STORJ       │  1972   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BAT         │  3285   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LSK         │  1370   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MANA        │  1567   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ADX         │  3988   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ADA         │   605   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XLM         │  1378   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ICX         │  3914   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RLC         │   387   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PIVX        │  3752   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ STEEM       │  3840   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ZIL         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ONT         │  3664   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WAN         │  4780   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SYS         │ 12723   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TUSD        │ 10000   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ZEN         │    70   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ THETA       │   636   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ IOTX        │ 18375   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DATA        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SC          │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DENT        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ARDR        │  6029   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HOT         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VET         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RVN         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ USDC        │ 10000   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ONG         │  3049   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FET         │   822   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ IOST        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CELR        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ATOM        │   112   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PHB         │   918   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TFUEL       │ 14736   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ONE         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ALGO        │  2154   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DOGE        │  2311   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DUSK        │  7987   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ANKR        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WIN         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ COS         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FUN         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CVC         │  5651   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CHZ         │ 12663   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BAND        │   689   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XTZ         │   697   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HBAR        │  2277   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NKN         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ STX         │   805   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KAVA        │  1348   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ARPA        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BCH         │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FTT         │   639   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TRY         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ EUR         │   428   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ OGN         │  8090   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BNT         │   673   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MBL         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ COTI        │ 10160   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ZAR         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SOL         │     2   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CTSI        │  6607   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HIVE        │  2497   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CHR         │  5104   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MDT         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ UAH         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ COMP        │    11   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SXP         │  2925   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SNX         │   744   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VTHO        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DGB         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MKR         │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RUNE        │   412   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DCR         │    30   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AVA         │   939   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ YFI         │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DAI         │ 10000   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ JST         │ 14612   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CRV         │   661   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SAND        │  1785   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NMR         │    37   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DOT         │   130   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LUNA        │  3395   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RSR         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PAXG        │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TRB         │    14   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WBTC        │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SUSHI       │   657   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KSM         │    33   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ EGLD        │    35   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DIA         │   680   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FIO         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ UMA         │   369   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BEL         │  2097   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ UNI         │    52   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ OXT         │  9387   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SUN         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AVAX        │    20   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FLM         │ 18115   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SCRT        │  2897   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CAKE        │   209   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ UTK         │ 16972   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XVS         │    81   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BRL         │    97   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AAVE        │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NEAR        │   207   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FIL         │   215   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ INJ         │    39   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AUDIO       │  8171   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CTK         │  1526   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AXS         │   211   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SLP         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ STRAX       │ 11664   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ROSE        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SKL         │ 16981   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GLM         │  2140   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GRT         │  5611   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ JUV         │   439   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PSG         │   309   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ 1INCH       │  2043   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ OG          │    36   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ATM         │   397   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ASR         │   212   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CELO        │  1700   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RIF         │  8896   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TRU         │ 17182   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CKB         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TWT         │   688   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SFP         │  1087   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DODO        │ 11261   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ACM         │   543   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AUCTION     │    52   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PHA         │  4868   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FIS         │  4757   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ OM          │  2422   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ POND        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DEGO        │   395   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ALICE       │  1390   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PERP        │  1935   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SUPER       │   839   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CFX         │  2906   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TKO         │  2662   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PUNDIX      │  1612   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TLM         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BAR         │   440   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FORTH       │   182   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BAKE        │ 12163   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SHIB        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ICP         │   104   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AR          │    76   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MASK        │   406   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LPT         │    72   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ATA         │ 11210   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GTC         │  1480   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MLN         │    63   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DEXE        │    68   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ C98         │ 10266   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ QNT         │     4   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FLOW        │  1237   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MINA        │  2786   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RAY         │   150   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FARM        │    17   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ QUICK       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MBOX        │  8962   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GHST        │  1148   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WAXP        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GNO         │     3   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XEC         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DYDX        │   844   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ IDEX        │ 17819   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ USDP        │   500   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GALA        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ILV         │    36   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ YGG         │  3285   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DF          │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FIDA        │  5860   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AGLD        │   749   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RAD         │   743   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RARE        │  9189   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SSV         │    55   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LAZIO       │   548   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CHESS       │  7041   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MOVR        │    86   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CITY        │   489   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ENS         │    22   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ QI          │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PORTO       │   514   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ JASMY       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AMP         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PYR         │   485   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ALCX        │    52   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SANTOS      │   280   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BICO        │  5208   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FLUX        │  2525   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FXS         │   187   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VOXEL       │  9002   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HIGH        │   981   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CVX         │   142   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PEOPLE      │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SPELL       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ JOE         │  3127   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ACH         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ IMX         │   964   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GLMR        │  7406   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ API3        │   510   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BTTC        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ACA         │ 17138   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XNO         │   576   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WOO         │  7418   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ALPINE      │   233   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ T           │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ASTR        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GMT         │ 12142   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KDA         │  1410   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ APE         │   871   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BIFI        │     2   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NEXO        │   393   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ REI         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LDO         │   413   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ OP          │   705   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ STG         │  3152   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LUNC        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GMX         │    34   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ POLYX       │  3919   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ APT         │   116   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PLN         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ OSMO        │  3020   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HFT         │  4969   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HOOK        │  4730   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MAGIC       │  2513   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HIFI        │  7629   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RPL         │    76   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RON         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GNS         │   226   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SYN         │  4175   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LQTY        │   614   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ USTC        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PROM        │    55   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ QKC         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ID          │  3177   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ARB         │  1008   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RDNT        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ARS         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ EDU         │  3837   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SUI         │   148   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PEPE        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FLOKI       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WBETH       │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MAV         │  6327   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PENDLE      │   107   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ARKM        │  1057   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WLD         │   562   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FDUSD       │ 10000   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SEI         │  1726   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CYBER       │   286   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ARK         │  1162   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ IQ          │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NTRN        │  5245   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TIA         │   311   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MEME        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ORDI        │    56   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BEAMX       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VIC         │  2243   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BLUR        │  6594   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VANRY       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AEUR        │   452   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ JTO         │   268   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ 1000SATS    │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BONK        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ACE         │   999   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NFP         │  8044   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AI          │  4176   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XAI         │ 10694   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MANTA       │  2508   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ALT         │ 15934   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ JUP         │  1012   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PYTH        │  3330   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RONIN       │  1042   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DYM         │  2415   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PIXEL       │ 17297   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ STRK        │  4061   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PORTAL      │ 12284   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AXL         │  1658   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WIF         │   617   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ METIS       │    33   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ JPY         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AEVO        │  5694   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BOME        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ETHFI       │   435   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ENA         │   750   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ W           │  6511   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TNSR        │  4383   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SAGA        │  2107   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MXN         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TAO         │     1   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ OMNI        │   162   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ REZ         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BB          │  3617   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NOT         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ COP         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ IO          │   967   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ZK          │  8886   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LISTA       │  2037   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ZRO         │   272   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ G           │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BANANA      │    26   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RENDER      │   145   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TON         │   160   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DOGS        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ EURI        │   428   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SLF         │ 17617   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ POL         │  1746   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NEIRO       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TURBO       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ 1MBABYDOGE  │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CATI        │  5837   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HMSTR       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ EIGEN       │   386   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BNSOL       │     2   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SCR         │  1517   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LUMIA       │  1635   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KAIA        │  3407   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ COW         │  1484   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CETUS       │  5520   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PNUT        │  2431   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ACT         │ 14130   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ USUAL       │  8578   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ THE         │  1499   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ACX         │  3605   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ORCA        │   222   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MOVE        │  4312   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ME          │   757   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VELODROME   │  9995   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VANA        │   128   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ 1000CAT     │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PENGU       │ 17250   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BIO         │  3494   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ D           │ 15780   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AIXBT       │  4784   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CGPT        │  6384   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ COOKIE      │  4209   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ S           │  1627   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SOLV        │ 11815   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TRUMP       │    59   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ANIME       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BERA        │   216   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ 1000CHEEMS  │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TST         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LAYER       │   985   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HEI         │  1168   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KAITO       │   503   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SHELL       │  4238   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RED         │   780   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GPS         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ EPIC        │   245   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BMT         │  8025   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ FORM        │   133   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ XUSD        │   500   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ CZK         │ 18466   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NIL         │  1858   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PARTI       │  2319   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MUBARAK     │ 18051   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TUT         │  7268   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BROCCOLI714 │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BANANAS31   │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ GUN         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BABY        │ 10956   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ONDO        │   539   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BIGTIME     │  9735   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ VIRTUAL     │   458   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KERNEL      │  2694   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WCT         │  1732   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HYPER       │  1705   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ INIT        │  1548   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SIGN        │  6808   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ STO         │  6304   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SYRUP       │   982   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ KMNO        │  9075   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SXT         │  6839   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NXPC        │   772   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ AWE         │  9684   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HAEDAL      │  3761   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ USD1        │   500   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HUMA        │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ A           │  1074   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SOPH        │ 17167   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ RESOLV      │  3431   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ HOME        │ 12774   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SPK         │  8206   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ NEWT        │  1939   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SAHARA      │  5454   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ LA          │  1559   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ ERA         │   708   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ C           │  2282   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TREE        │  1538   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ A2Z         │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ TOWNS       │ 18446   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PROVE       │   580   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ BFUSD       │   500   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ PLUME       │  6186   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ DOLO        │  2918   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ MITO        │  2623   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ WLFI        │  2723   │        0 │
# ├─────────────┼─────────┼──────────┤
# │ SOMI        │   954   │        0 │
# ╘═════════════╧═════════╧══════════╛

# %% [markdown]
# Main Trading loop, runs until you stop

# %%
def startTradingLoop(symbol, buy_price_threshold, sell_price_threshold, trade_quantity):
    position = False # Used to apply single buy sell strategy
    while True:
        print("\n\nCurrent position : ", position)

        current_price = get_current_price(symbol)
        print(f"\nCurrent price of {symbol}: {current_price}")

        if not position and current_price <= buy_price_threshold:
            print(f"\nPrice is below {buy_price_threshold}, placing buy order.")
            place_buy_order(symbol, trade_quantity)
            position = True
        elif current_price >= sell_price_threshold:
            print(f"\nPrice is above {sell_price_threshold}, placing sell order.")
            place_sell_order(symbol, trade_quantity)
            position = False
        else:
            print("\nNo trading action taken.")

        time.sleep(10)  # Wait for 10 seconds before checking again

# %% [markdown]
# Running the bot in main

# %%
if __name__ == "__main__":
    symbol = "BTCUSDT"
    trade_quantity = 0.001 
    buy_price_threshold = 113850
    sell_price_threshold = 113880
    startTradingLoop(symbol, buy_price_threshold, sell_price_threshold, trade_quantity)
# Out:
# Current position :  True
#
# Current price of BTCUSDT: 113811.9
#
# No trading action taken.
#
#
# Current position :  True
#
# Current price of BTCUSDT: 113811.89
#
# No trading action taken.
#
#
# Current position :  True
#
# Current price of BTCUSDT: 113819.01
#
# No trading action taken.
#
#
# Current position :  True
#
# Current price of BTCUSDT: 113811.9
#
# No trading action taken.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 7
#       5 buy_price_threshold = 113850
#       6 sell_price_threshold = 113880
# ----> 7 startTradingLoop(symbol, buy_price_threshold, sell_price_threshold, trade_quantity)
#
# Cell In[41], line 20, in startTradingLoop(symbol, buy_price_threshold, sell_price_threshold, trade_quantity)
#      17 else:
#      18     print("\nNo trading action taken.")
# ---> 20 time.sleep(10)
#
# KeyboardInterrupt:
